# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils.np_utils import to_categorical
from keras.models import Model
from keras import backend
import random
import csv
import cv2
from tqdm import tqdm, notebook
from time import sleep
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# function for reading the images
# arguments: path to the traffic sign data, for example './GTSRB/Training'
# returns: list of images, list of corresponding labels 
def readTrafficSigns(rootpath, dim):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.

    Arguments: path to the traffic sign data, for example './GTSRB/Training'
    Returns:   list of images, list of corresponding labels'''
    image = np.array([]) #helper to resize images to dim
    images = [] # images
    labels = [] # corresponding labels
    # loop over all classes
    for c in notebook.tqdm(range(0,43), desc="read classes"):
        prefix = rootpath + '/' + format(c, '05d') + '/' # subdirectory for class
        gtFile = open(prefix + 'GT-'+ format(c, '05d') + '.csv') # annotations file
        gtReader = csv.reader(gtFile, delimiter=';') # csv parser for annotations file
        gtReader.__next__() # skip header
        sleep(0.001)
        for row in gtReader:
            image = plt.imread(prefix + row[0])
            image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
            images.append(image)
            labels.append(row[7]) # the 8th column is the label
        gtFile.close()
    img = np.asarray(images)
    lab = np.asarray(labels, dtype=np.uint8)
    return img, lab

# %%
# function for reading the images
# arguments: path to the traffic sign data, for example './GTSRB/Training'
# returns: list of images, list of corresponding labels 
def readTrafficSigns_test(rootpath, dim):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.

    Arguments: path to the traffic sign data, for example './GTSRB/Training'
    Returns:   list of images, list of corresponding labels'''
    image = np.array([]) #helper to resize images to dim
    images = [] # images
    labels = [] # corresponding labels
    # loop over all classes
    prefix = rootpath + '/'
    gtFile = open(prefix + 'GT-final_test.csv') # annotations file
    gtReader = csv.reader(gtFile, delimiter=';') # csv parser for annotations file
    gtReader.__next__() # skip header
    sleep(0.001)
    for row in notebook.tqdm(gtReader, desc="images"):
        image = plt.imread(prefix + row[0])
        image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
        images.append(image)
        labels.append(row[7]) # the 8th column is the label
        sleep(0.001)
    gtFile.close()
    img = np.asarray(images)
    lab = np.asarray(labels, dtype=np.uint8)
    return img, lab

# %%
path_train = "C:/Users/Thomas/Desktop/GTSRB/Final_Training/Images"
path_test = "C:/Users/Thomas/Desktop/GTSRB/Final_Test/Images"

# %%
# size in which the images should be resized
dim = (32,32)
X_train_all, y_train_all = readTrafficSigns(path_train, dim)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='read classes', max=43.0, style=ProgressStyle(description_…

# %%
X_test, y_test = readTrafficSigns_test(path_test, dim)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='images', max=1.0, style=ProgressStyle(d…

# %%
# read signames from csv
data = pd.read_csv("C:/Users/Thomas/Desktop/tsp/input/labels/signnames.csv", sep=";", encoding="mac_latin2")
data
# Out:
#     ClassId                                           SignName  \
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vehicles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vehicles
# 16       16           Vehicles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vehicles over 3.5 metric ...
#
#                            SignNameGerman
# 0                             Max. 20km/h
# 1                             Max. 30km/h
# 2                             Max. 50km/h
# 3                             Max. 60km/h
# 4                             Max. 70km/h
# 5                             Max. 80km/h
# 6                        Ende Max. 80km/h
# 7                            Max. 100km/h
# 8                            Max. 120km/h
# 9                          Ueberholverbot
# 10           ‹berholverbot fŁr Fzg > 3,5t
# 11      Vorfahrt an der nšchsten Kreuzung
# 12                               Vorfahrt
# 13                      Vorfahrt gewšhren
# 14                Halt, Vorfahrt gewšhren
# 15                 Verbot aller Fahrzeuge
# 16          Verbot aller Fahrzeuge > 3,5t
# 17                      Einfahrt Verboten
# 18                         Gefahrenstelle
# 19                            Kurve links
# 20                           Kurve rechts
# 21                            Doppelkurve
# 22                       Unebene Fahrbahn
# 23                           Rutschgefahr
# 24               Rechts verengte Fahrbahn
# 25                          Arbeitsstelle
# 26                     Lichtzeichenanlage
# 27                              FuŖgšnger
# 28                                 Kinder
# 29                              Radfahrer
# 30                      Schnee-/Eisglštte
# 31                            Wildwechsel
# 32  Ende aller Geschw. Und ‹berholverbote
# 33                   Fahrtrichtung rechts
# 34                    Fahrtrichtung links
# 35                Fahrtrichtung geradeaus
# 36    Fahrtrichtung geradeaus oder rechts
# 37     Fahrtrichtung geradeaus oder links
# 38                    Rechts vorbeifahren
# 39                     Links vorbeifahren
# 40                           Kreisverkehr
# 41                     Ende ‹berholverbot
# 42      Ende ‹berholverbot fŁr Fzg > 3,5t

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_all, y_train_all, test_size=0.1, random_state=1) # 0.125 x 0.8 = 0.1

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (35288, 32, 32, 3)
# (35288,)
# (3921, 32, 32, 3)
# (3921,)

# %%
dim_rgb = dim + (3,)
dim_rgb
# Out:
# (32, 32, 3)

# %%
def convert_grayscale(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return image

def equalize_histogram(image):
    image = cv2.equalizeHist(image)
    return image

def preprocessing_images(image):
    image = convert_grayscale(image)
    image = equalize_histogram(image)
    # normalisierung
    image = image/255
    return image

# %%
X_train_pcd = np.array(list(map(preprocessing_images, X_train)))
X_val_pcd = np.array(list(map(preprocessing_images, X_val)))
X_test_pcd = np.array(list(map(preprocessing_images, X_test)))

# %%
# adding depth for cnn
X_train_pcd = X_train_pcd.reshape(X_train_pcd.shape[0],X_train_pcd.shape[1],X_train_pcd.shape[2],1)
X_val_pcd = X_val_pcd.reshape(X_val_pcd.shape[0],X_val_pcd.shape[1],X_val_pcd.shape[2],1)
X_test_pcd = X_test_pcd.reshape(X_test_pcd.shape[0],X_test_pcd.shape[1],X_test_pcd.shape[2],1)

# %%
number_classes = 43

# one hot encode the values
y_train_pcd = to_categorical(y_train, number_classes)
y_val_pcd = to_categorical(y_val, number_classes)
y_test_pcd = to_categorical(y_test, number_classes)

# %%
def leNet():
    model = Sequential()
    model.add(Conv2D(30, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(15, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(500, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.01), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def leNet_moreFilter():
    model = Sequential()
    model.add(Conv2D(60, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(30, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(500, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.01), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def leNet_moreFilter_lowerLr():
    model = Sequential()
    model.add(Conv2D(60, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(30, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(500, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def leNet_moreFilter_lowerLr_higherDense():
    model = Sequential()
    model.add(Conv2D(60, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(30, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(2000, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def leNet_moreFilter_lowerLr_higherDense_addLayer():
    model = Sequential()
    model.add(Conv2D(60, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(30, (3,3), activation="relu"))
    model.add(Conv2D(30, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(1000, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def leNet_moreFilter_lowerLr_higherDense_addLayer_addDropout():
    model = Sequential()
    model.add(Conv2D(60, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(30, (3,3), activation="relu"))
    model.add(Conv2D(30, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.5))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(500, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
#actual prefered
def leNet_lowerLr_higherDense_addLayer_addDropout():
    model = Sequential()
    model.add(Conv2D(30, (5,5), input_shape=(32,32,1), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    # adding 2. conv layer
    model.add(Conv2D(15, (3,3), activation="relu"))
    model.add(Conv2D(15, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.5))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(500, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def leNet_lowerLr_higherDense_addLayer_addDropout2():
    model = Sequential()
    model.add(Conv2D(30, (5,5), input_shape=(32,32,1), activation="relu"))
    model.add(Conv2D(30, (5,5), activation="relu"))
    # pooling layer - reduces the shape from 24x24 (from convolutional) to here 12x12 (cause of 2x2 pool size))
    # argument
    #   1. pool size (tupel)
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    # adding 2. conv layer
    model.add(Conv2D(15, (3,3), activation="relu"))
    model.add(Conv2D(15, (3,3), activation="relu"))
    # 2. pooling layer
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.5))
    # flattens the data
    model.add(Flatten())
    # creating the neural network
    # input nodes - play with it
    model.add(Dense(500, activation="relu"))
    # dropout layer (more than one possible) - randomly turns nodes off during training to get a more generalized cnn
    # 0.5 = 50%, propsed rate by researchers
    model.add(Dropout(0.5))
    # output layer
    model.add(Dense(number_classes, activation="softmax"))
    # compile model
    model.compile(Adam(lr=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %% [markdown]
# # repeat here!!!

# %%
backend.clear_session()
del model

epochs_cnn = 100

model = leNet_lowerLr_higherDense_addLayer_addDropout2()
history = model.fit(X_train_pcd, y_train_pcd, epochs=epochs_cnn, validation_data=(X_val_pcd, y_val_pcd), batch_size=200, verbose=1, shuffle=1)
# Out:
# Epoch 1/100
#   1/177 [..............................] - ETA: 6s - loss: 3.7697 - accuracy: 0.0050WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.0390s). Check your callbacks.
# 177/177 [==============================] - 6s 32ms/step - loss: 3.5781 - accuracy: 0.0538 - val_loss: 3.4207 - val_accuracy: 0.1398
# Epoch 2/100
# 177/177 [==============================] - 2s 14ms/step - loss: 3.1052 - accuracy: 0.1975 - val_loss: 2.2572 - val_accuracy: 0.4573
# Epoch 3/100
# 177/177 [==============================] - 2s 14ms/step - loss: 2.1922 - accuracy: 0.4054 - val_loss: 1.4175 - val_accuracy: 0.6266
# Epoch 4/100
# 177/177 [==============================] - 3s 14ms/step - loss: 1.7038 - accuracy: 0.5108 - val_loss: 1.0340 - val_accuracy: 0.7564
# Epoch 5/100
# 177/177 [==============================] - 3s 14ms/step - loss: 1.4072 - accuracy: 0.5844 - val_loss: 0.8198 - val_accuracy: 0.8097
# Epoch 6/100
# 177/177 [==============================] - 2s 14ms/step - loss: 1.2092 - accuracy: 0.6350 - val_loss: 0.6554 - val_accuracy: 0.8488
# Epoch 7/100
# 177/177 [==============================] - 2s 14ms/step - loss: 1.0736 - accuracy: 0.6775 - val_loss: 0.5587 - val_accuracy: 0.8732
# Epoch 8/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.9618 - accuracy: 0.7062 - val_loss: 0.4985 - val_accuracy: 0.8896
# Epoch 9/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.8866 - accuracy: 0.7274 - val_loss: 0.4485 - val_accuracy: 0.8982
# Epoch 10/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.8178 - accuracy: 0.7480 - val_loss: 0.3955 - val_accuracy: 0.9059
# Epoch 11/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.7501 - accuracy: 0.7694 - val_loss: 0.3593 - val_accuracy: 0.9100
# Epoch 12/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.7007 - accuracy: 0.7827 - val_loss: 0.3214 - val_accuracy: 0.9214
# Epoch 13/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.6607 - accuracy: 0.7980 - val_loss: 0.2960 - val_accuracy: 0.9273
# Epoch 14/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.6226 - accuracy: 0.8093 - val_loss: 0.2709 - val_accuracy: 0.9306
# Epoch 15/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.5875 - accuracy: 0.8182 - val_loss: 0.2572 - val_accuracy: 0.9362
# Epoch 16/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.5572 - accuracy: 0.8278 - val_loss: 0.2428 - val_accuracy: 0.9406
# Epoch 17/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.5341 - accuracy: 0.8316 - val_loss: 0.2193 - val_accuracy: 0.9419
# Epoch 18/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.5084 - accuracy: 0.8445 - val_loss: 0.2103 - val_accuracy: 0.9482
# Epoch 19/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.4846 - accuracy: 0.8521 - val_loss: 0.2021 - val_accuracy: 0.9480
# Epoch 20/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.4689 - accuracy: 0.8530 - val_loss: 0.1817 - val_accuracy: 0.9526
# Epoch 21/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.4452 - accuracy: 0.8606 - val_loss: 0.1756 - val_accuracy: 0.9526
# Epoch 22/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.4378 - accuracy: 0.8641 - val_loss: 0.1681 - val_accuracy: 0.9536
# Epoch 23/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.4193 - accuracy: 0.8704 - val_loss: 0.1639 - val_accuracy: 0.9587
# Epoch 24/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.4067 - accuracy: 0.8745 - val_loss: 0.1537 - val_accuracy: 0.9625
# Epoch 25/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3903 - accuracy: 0.8796 - val_loss: 0.1474 - val_accuracy: 0.9630
# Epoch 26/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.3742 - accuracy: 0.8825 - val_loss: 0.1398 - val_accuracy: 0.9643
# Epoch 27/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3669 - accuracy: 0.8863 - val_loss: 0.1398 - val_accuracy: 0.9635
# Epoch 28/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3598 - accuracy: 0.8877 - val_loss: 0.1372 - val_accuracy: 0.9648
# Epoch 29/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3438 - accuracy: 0.8943 - val_loss: 0.1262 - val_accuracy: 0.9684
# Epoch 30/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3409 - accuracy: 0.8939 - val_loss: 0.1212 - val_accuracy: 0.9717
# Epoch 31/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3262 - accuracy: 0.8988 - val_loss: 0.1229 - val_accuracy: 0.9689
# Epoch 32/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3181 - accuracy: 0.9018 - val_loss: 0.1104 - val_accuracy: 0.9745
# Epoch 33/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3157 - accuracy: 0.9020 - val_loss: 0.1072 - val_accuracy: 0.9730
# Epoch 34/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3058 - accuracy: 0.9038 - val_loss: 0.1066 - val_accuracy: 0.9725
# Epoch 35/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.3018 - accuracy: 0.9056 - val_loss: 0.1037 - val_accuracy: 0.9750
# Epoch 36/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2894 - accuracy: 0.9116 - val_loss: 0.0963 - val_accuracy: 0.9778
# Epoch 37/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2808 - accuracy: 0.9116 - val_loss: 0.0957 - val_accuracy: 0.9763
# Epoch 38/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2788 - accuracy: 0.9133 - val_loss: 0.0916 - val_accuracy: 0.9788
# Epoch 39/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2709 - accuracy: 0.9171 - val_loss: 0.0991 - val_accuracy: 0.9776
# Epoch 40/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2649 - accuracy: 0.9170 - val_loss: 0.0874 - val_accuracy: 0.9791
# Epoch 41/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2623 - accuracy: 0.9189 - val_loss: 0.0861 - val_accuracy: 0.9796
# Epoch 42/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.2537 - accuracy: 0.9218 - val_loss: 0.0802 - val_accuracy: 0.9799
# Epoch 43/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.2500 - accuracy: 0.9235 - val_loss: 0.0815 - val_accuracy: 0.9809
# Epoch 44/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.2494 - accuracy: 0.9222 - val_loss: 0.0774 - val_accuracy: 0.9814
# Epoch 45/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.2425 - accuracy: 0.9259 - val_loss: 0.0753 - val_accuracy: 0.9793
# Epoch 46/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2446 - accuracy: 0.9245 - val_loss: 0.0779 - val_accuracy: 0.9814
# Epoch 47/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2318 - accuracy: 0.9268 - val_loss: 0.0720 - val_accuracy: 0.9809
# Epoch 48/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2301 - accuracy: 0.9290 - val_loss: 0.0703 - val_accuracy: 0.9816
# Epoch 49/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2218 - accuracy: 0.9298 - val_loss: 0.0717 - val_accuracy: 0.9816
# Epoch 50/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2155 - accuracy: 0.9331 - val_loss: 0.0661 - val_accuracy: 0.9829
# Epoch 51/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2197 - accuracy: 0.9321 - val_loss: 0.0686 - val_accuracy: 0.9842
# Epoch 52/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2105 - accuracy: 0.9331 - val_loss: 0.0631 - val_accuracy: 0.9852
# Epoch 53/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2068 - accuracy: 0.9380 - val_loss: 0.0675 - val_accuracy: 0.9839
# Epoch 54/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2062 - accuracy: 0.9367 - val_loss: 0.0624 - val_accuracy: 0.9842
# Epoch 55/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.2027 - accuracy: 0.9364 - val_loss: 0.0624 - val_accuracy: 0.9837
# Epoch 56/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1973 - accuracy: 0.9388 - val_loss: 0.0619 - val_accuracy: 0.9837
# Epoch 57/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1996 - accuracy: 0.9380 - val_loss: 0.0566 - val_accuracy: 0.9855
# Epoch 58/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1933 - accuracy: 0.9402 - val_loss: 0.0578 - val_accuracy: 0.9855
# Epoch 59/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1871 - accuracy: 0.9421 - val_loss: 0.0573 - val_accuracy: 0.9865
# Epoch 60/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1903 - accuracy: 0.9405 - val_loss: 0.0539 - val_accuracy: 0.9847
# Epoch 61/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1885 - accuracy: 0.9410 - val_loss: 0.0532 - val_accuracy: 0.9878
# Epoch 62/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1886 - accuracy: 0.9402 - val_loss: 0.0550 - val_accuracy: 0.9867
# Epoch 63/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1827 - accuracy: 0.9439 - val_loss: 0.0523 - val_accuracy: 0.9878
# Epoch 64/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1815 - accuracy: 0.9436 - val_loss: 0.0564 - val_accuracy: 0.9850
# Epoch 65/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1807 - accuracy: 0.9437 - val_loss: 0.0497 - val_accuracy: 0.9880
# Epoch 66/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1702 - accuracy: 0.9469 - val_loss: 0.0523 - val_accuracy: 0.9860
# Epoch 67/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1755 - accuracy: 0.9458 - val_loss: 0.0516 - val_accuracy: 0.9880
# Epoch 68/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1724 - accuracy: 0.9453 - val_loss: 0.0472 - val_accuracy: 0.9883
# Epoch 69/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1683 - accuracy: 0.9483 - val_loss: 0.0479 - val_accuracy: 0.9872
# Epoch 70/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1725 - accuracy: 0.9468 - val_loss: 0.0459 - val_accuracy: 0.9901
# Epoch 71/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1643 - accuracy: 0.9475 - val_loss: 0.0447 - val_accuracy: 0.9895
# Epoch 72/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1581 - accuracy: 0.9510 - val_loss: 0.0458 - val_accuracy: 0.9880
# Epoch 73/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1562 - accuracy: 0.9503 - val_loss: 0.0470 - val_accuracy: 0.9872
# Epoch 74/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1578 - accuracy: 0.9506 - val_loss: 0.0453 - val_accuracy: 0.9895
# Epoch 75/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1546 - accuracy: 0.9526 - val_loss: 0.0431 - val_accuracy: 0.9895
# Epoch 76/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1523 - accuracy: 0.9535 - val_loss: 0.0440 - val_accuracy: 0.9885
# Epoch 77/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1547 - accuracy: 0.9516 - val_loss: 0.0424 - val_accuracy: 0.9911
# Epoch 78/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1487 - accuracy: 0.9533 - val_loss: 0.0421 - val_accuracy: 0.9906
# Epoch 79/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1491 - accuracy: 0.9545 - val_loss: 0.0398 - val_accuracy: 0.9913
# Epoch 80/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1446 - accuracy: 0.9555 - val_loss: 0.0407 - val_accuracy: 0.9903
# Epoch 81/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1467 - accuracy: 0.9526 - val_loss: 0.0414 - val_accuracy: 0.9893
# Epoch 82/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1430 - accuracy: 0.9554 - val_loss: 0.0413 - val_accuracy: 0.9903
# Epoch 83/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1397 - accuracy: 0.9570 - val_loss: 0.0382 - val_accuracy: 0.9918
# Epoch 84/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1368 - accuracy: 0.9576 - val_loss: 0.0374 - val_accuracy: 0.9908
# Epoch 85/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1407 - accuracy: 0.9564 - val_loss: 0.0368 - val_accuracy: 0.9923
# Epoch 86/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1348 - accuracy: 0.9581 - val_loss: 0.0358 - val_accuracy: 0.9921
# Epoch 87/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1355 - accuracy: 0.9582 - val_loss: 0.0378 - val_accuracy: 0.9921
# Epoch 88/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1342 - accuracy: 0.9579 - val_loss: 0.0360 - val_accuracy: 0.9916
# Epoch 89/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1375 - accuracy: 0.9574 - val_loss: 0.0358 - val_accuracy: 0.9918
# Epoch 90/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1289 - accuracy: 0.9602 - val_loss: 0.0363 - val_accuracy: 0.9921
# Epoch 91/100
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1368 - accuracy: 0.9576 - val_loss: 0.0347 - val_accuracy: 0.9918
# Epoch 92/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1288 - accuracy: 0.9600 - val_loss: 0.0341 - val_accuracy: 0.9911
# Epoch 93/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1249 - accuracy: 0.9609 - val_loss: 0.0335 - val_accuracy: 0.9921
# Epoch 94/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1231 - accuracy: 0.9628 - val_loss: 0.0341 - val_accuracy: 0.9923
# Epoch 95/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1305 - accuracy: 0.9598 - val_loss: 0.0335 - val_accuracy: 0.9921
# Epoch 96/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1226 - accuracy: 0.9614 - val_loss: 0.0319 - val_accuracy: 0.9931
# Epoch 97/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1262 - accuracy: 0.9609 - val_loss: 0.0311 - val_accuracy: 0.9923
# Epoch 98/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1239 - accuracy: 0.9607 - val_loss: 0.0344 - val_accuracy: 0.9911
# Epoch 99/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1220 - accuracy: 0.9623 - val_loss: 0.0323 - val_accuracy: 0.9929
# Epoch 100/100
# 177/177 [==============================] - 3s 14ms/step - loss: 0.1176 - accuracy: 0.9634 - val_loss: 0.0313 - val_accuracy: 0.9929

# %%
print(model.summary())
print()
print()

plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("accuracy")
plt.xlabel("epoch")
plt.legend(["accuracy", "validation_accuracy"])
print("number of epochs", epochs_cnn)
print()
print("Train Accuracy", round(history.history["accuracy"][epochs_cnn-1],3))
print("Val Accuracy", round(history.history["val_accuracy"][epochs_cnn-1],3))


score = model.evaluate(X_test_pcd, y_test_pcd, verbose = 0)
print("Test Score    ", round(score[0],3)) #evaluation of the loss function for a given input
print("Test Accuracy ", round(score[1],3))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 30)        780
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 30)        22530
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 30)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 15)        4065
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 15)          2040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 15)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 15)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 240)               0
# _________________________________________________________________
# dense (Dense)                (None, 500)               120500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                21543
# =================================================================
# Total params: 171,458
# Trainable params: 171,458
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# number of epochs 100
#
# Train Accuracy 0.963
# Val Accuracy 0.993
# Test Score     0.119
# Test Accuracy  0.964

# %%
#model.save("model_lr_dr_addL_Dense500_Epochs100_v2")
# Out:
# INFO:tensorflow:Assets written to: model_lr_dr_addL_Dense500_Epochs100_v2\assets

# %%
#reconstructed_model = keras.models.load_model("model_lr_dr_addL_Dense500_Epochs100_v2")

# %%
#score = model.evaluate(X_test_pcd, y_test_pcd, verbose = 0)
#print("Test Score    ", round(score[0],3)) #evaluation of the loss function for a given input
#print("Test Accuracy ", round(score[1],3))
